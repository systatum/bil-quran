# %% [markdown]
# # Default Setting

# %%
from shared.env import BackendEnv as Env
from backend.setting_prototype import Setting
from backend.llm_model_source import ModelSource
from pathlib import Path


def get_setting() -> Setting:
    return Setting(
        LLM_TEMP_DIR=Path(Env.get().MOUNT_ROOT) / "hg_download",
        LLM_MODEL_DIR=Path(Env.get().MOUNT_ROOT) / "models",
        LLM_MODELS={
            # Baseline
            "qwen3-8b": ModelSource(
                hf_repo_url="https://huggingface.co/Qwen/Qwen3-8B-GGUF",
                filename="Qwen3-8B-Q4_K_M.gguf",
            ),
            "qwen3-14b": ModelSource(
                hf_repo_url="https://huggingface.co/Qwen/Qwen3-14B-GGUF",
                filename="Qwen3-14B-Q4_K_M.gguf",
            ),
            "gemma-3-27b": ModelSource(
                hf_repo_url="https://huggingface.co/unsloth/gemma-3-27b-it-GGUF",
                filename="gemma-3-27b-it-Q4_K_M.gguf",
            ),
            "qwen3-32b": ModelSource(
                hf_repo_url="https://huggingface.co/bartowski/Qwen_Qwen3-32B-GGUF",
                filename="Qwen_Qwen3-32B-Q4_K_M.gguf",
            ),
            "llama-3.3-70b": ModelSource(
                hf_repo_url="https://huggingface.co/unsloth/Llama-3.3-70B-Instruct-GGUF",
                filename="Llama-3.3-70B-Instruct-Q4_K_M.gguf",
            ),
        },
        LLM_GPU_ENABLED=True,
        LLM_CONTEXT_SIZE=32768,
        LLM_MAX_LOADED=1,
        APP_TOKEN=Env.get().API_KEY,
    )

# %% [markdown]
# # Testing Settings

# %%
from shared.env import BackendEnv as Env
from backend.setting_prototype import Setting
from backend.llm_model_source import ModelSource
from pathlib import Path


def get_setting() -> Setting:
    return Setting(
        LLM_TEMP_DIR=Path(Env.get().MOUNT_ROOT) / "hg_download",
        LLM_MODEL_DIR=Path(Env.get().MOUNT_ROOT) / "models",
        LLM_MODELS={
            "qwen3-8b": ModelSource(
                hf_repo_url="https://huggingface.co/Qwen/Qwen3-8B-GGUF",
                filename="Qwen3-8B-Q4_K_M.gguf",
            ),
        },
        LLM_GPU_ENABLED=True,
        LLM_CONTEXT_SIZE=32768,
        LLM_MAX_LOADED=1,
        APP_TOKEN=Env.get().API_KEY,
    )
