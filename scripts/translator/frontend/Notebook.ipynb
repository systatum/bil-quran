# %%
# %load_ext autoreload
# %autoreload 2
from shared import api
from shared.env import FrontendEnv
from shared.apiclient import APIClient
from frontend.structs import *
from frontend.experiment import ExperimentRunner
from datetime import datetime, timezone
from dataclasses import asdict
from pathlib import Path
from time import perf_counter
import sys

# %%
client = APIClient(setting=APIClient.Setting(token=FrontendEnv.get().API_KEY_LOCAL))
# client = APIClient(setting=APIClient.Setting(token=FrontendEnv.get().API_KEY_REMOTE, base_url="http://127.0.0.1:8049/"))

# %%
models = client.models()
models
# Out:
# ['qwen2.5-1.5b', 'smollm2-1.7b']

# %%
# display(client.translate("Hello, you can call me Agus", source_language="english", target_language="indonesian", model=models[0], prompt_setting=api.internal.PromptSetting()))
# display(client.rate("Hello, you can call me Agus", "Halo, Anda bisa panggil saya Agus"))
# display(client.compare("Hello, you can call me Agus", "Halo, Anda bisa panggil saya Agus", "Halo nama saya Agus"))
# display(client.health())

# %%
def text_loader(path: str):
    with open(path) as file:
        return file.read()

prompts = [
    ExperimentPrompt(
        name="minimal",
        setting=api.internal.PromptSetting(
            system_prompt=(
                "You are an assistant who translates. "
                "The first line of the input is source and target language specification."
            ),
            prompt_format="{source_language} -> {target_language}\n{text}",
        ),
    ),
    ExperimentPrompt(
        name="professional",
        setting=api.internal.PromptSetting(
            system_prompt="""You are a professional translation engine.

Translate the user's text faithfully from the specified source language to the specified target language.

Rules:
- Preserve the meaning exactly.
- Do not answer the user's request.
- Do not summarize.
- Do not explain.
- Do not add or remove information.
- Preserve formatting where possible.
- Return only the translation text.""",
            prompt_format="""Source language: {source_language}
Target language: {target_language}

Text:
{text}""",
        ),
    ),
    ExperimentPrompt(
        name="verbose",
        setting=api.internal.PromptSetting(
            system_prompt=text_loader("frontend/verbose.txt"),
            prompt_format="""Translate the following text.

Source language: {source_language}
Target language: {target_language}

Input:
{text}

Translation:""",
        ),
    ),
]

# %%
import json
texts = []
for i in range(114, 115)[::-1]:
    data = json.load(open("../../../public/quran/exegesis/mirali/en-US/{}.json".format(i)))
    texts.extend(data["exegesis"].values())
len(texts)
# Out:
# 6

# %%
language = ExperimentLanguage(source_language="english", target_language="indonesian")
run = ExperimentRunCommand(
    language_pairs=[("English", "Indonesian")],
    models=models[:1],
    prompt_settings={prompt.name: prompt.setting for prompt in prompts},
    note="TL of mirali exegesis with cloud model, context size 32768",
    texts=texts[:1]
)

runner = ExperimentRunner(client)
run_id = runner.create(run, force_new=True)
runner.run(run_id=run_id)
# Out:
# Translating | Batch 1/1 | Model qwen2.5-1.5b | Done 1/3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 12
#       8 )
#       9
#      10 runner = ExperimentRunner(client)
#      11 run_id = runner.create(run, force_new=True)
# ---> 12 runner.run(run_id=run_id)
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/frontend/frontend/experiment.py:81, in ExperimentRunner.run(self, run_id)
#      79 run_dir = self._run_dirpath(metadata.created_at)
#      80 batch_ids = list(metadata.batches.keys())
# ---> 81 self._process_run(metadata, batch_ids, run_dir)
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/frontend/frontend/experiment.py:90, in ExperimentRunner._process_run(self, metadata, batch_ids, run_dir)
#      83 def _process_run(
#      84     self,
#      85     metadata: ExperimentRunMetadata,
#      86     batch_ids: list[UUID],
#      87     run_dir: Path,
#      88 ):
#      89     for i, batch_id in enumerate(batch_ids, 1):
# ---> 90         progress = self._translate_batch(
#      91             metadata,
#      92             batch_id,
#      93             run_dir,
#      94             i,
#      95             len(batch_ids),
#      96         )
#      98         metadata.batches[batch_id].progress = progress
#      99         if metadata.progress == "not started":
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/frontend/frontend/experiment.py:176, in ExperimentRunner._translate_batch(self, metadata, batch_id, run_dir, batch_number, batch_total)
#     171 setting = ExperimentSetting(prompt=prompt_setting, model=model)
#     172 input = ExperimentInput(
#     173     text=text, language=language, setting=setting
#     174 )
# --> 176 translated = self._translate(input=input, allow_fail=True)
#     177 with open(
#     178     self._translated_record_filepath(batch_dir), "ab"
#     179 ) as file:
#     180     file.write(
#     181         TypeAdapter(ExperimentTranslatedRecord).dump_json(
#     182             translated
#     183         )
#     184         + b"\n"
#     185     )
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/frontend/frontend/experiment.py:340, in ExperimentRunner._translate(self, input, allow_fail)
#     338 start_time = perf_counter()
#     339 try:
# --> 340     translation = self._client.translate(
#     341         text=input.text.text,
#     342         source_language=input.language.source_language,
#     343         target_language=input.language.target_language,
#     344         model=input.setting.model,
#     345         prompt_setting=input.setting.prompt.setting,
#     346     )
#     347 except Exception as e:
#     348     if not allow_fail:
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/shared/shared/apiclient.py:92, in APIClient.translate(self, text, source_language, target_language, model, prompt_setting)
#      84 translate_input = api.internal.TranslateInput(
#      85     source_language=source_language, target_language=target_language, text=text
#      86 )
#      87 request = api.internal.TranslateAPIRequest(
#      88     api.internal.TranslateJob(
#      89         translate_input=translate_input, setting=prompt_setting, model=model
#      90     )
#      91 )
# ---> 92 return self._translate(request).value
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/shared/shared/apiclient.py:125, in APIClient._translate(self, request)
#     118 def _translate(
#     119     self, request: api.internal.TranslateAPIRequest
#     120 ) -> api.internal.TranslateJobResultOk:
#     121     """
#     122     RAISES:
#     123         APIError
#     124     """
# --> 125     return self._request(
#     126         "/translate",
#     127         TypeAdapter(api.internal.TranslateJobResultOk),
#     128         request.model_dump_json(),
#     129     )
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/shared/shared/apiclient.py:175, in APIClient._request(self, path, adapter, data, force_post)
#     173 try:
#     174     if data is not None:
# --> 175         response: requests.Response = self.session.post(
#     176             self.setting.base_url + path, data=data.encode("utf-8")
#     177         )
#     178     elif force_post:
#     179         response: requests.Response = self.session.post(
#     180             self.setting.base_url + path
#     181         )
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/requests/sessions.py:712, in Session.post(self, url, data, json, **kwargs)
#     695 def post(
#     696     self,
#     697     url: _t.UriType,
#    (...)    700     **kwargs: Unpack[_t.PostKwargs],
#     701 ) -> Response:
#     702     r"""Sends a POST request. Returns :class:`Response` object.
#     703
#     704     :param url: URL for the new :class:`Request` object.
#    (...)    709     :rtype: requests.Response
#     710     """
# --> 712     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File <string>:5, in raise_from(value, from_value)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/.cache/uv/builds-v0/.tmpIiTFqI/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/http/client.py:1415, in HTTPConnection.getresponse(self)
#    1413 try:
#    1414     try:
# -> 1415         response.begin()
#    1416     except ConnectionError:
#    1417         self.close()
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/http/client.py:330, in HTTPResponse.begin(self)
#     328 # read until we get a non-100 response
#     329 while True:
# --> 330     version, status, reason = self._read_status()
#     331     if status != CONTINUE:
#     332         break
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/http/client.py:291, in HTTPResponse._read_status(self)
#     290 def _read_status(self):
# --> 291     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     292     if len(line) > _MAXLINE:
#     293         raise LineTooLong("status line")
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
