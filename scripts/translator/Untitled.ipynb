# %%
from src.util import Result, OkVariant, ErrVariant

# %%
r = Result.ok(1) 
r
# Out:
# Result(root=OkVariant(status='ok', value=1))

# %%
e = Result.err("err")
e
# Out:
# Result(root=ErrVariant(status='err', error='err'))

# %%
p: Result[int, str]
p = Result[int, str].ok("err")
p
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 p: Result[int, str]
# ----> 2 p = Result[int, str].ok("err")
#       3 p
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/src/util.py:30, in Result.ok(cls, value)
#      28 @classmethod
#      29 def ok(cls, value: V) -> Self:
# ---> 30     return cls(OkVariant(value=value))
#
# File ~/Repos/orgs-active/systatum/bil-quran/scripts/translator/env/lib/python3.11/site-packages/pydantic/root_model.py:68, in RootModel.__init__(self, root, **data)
#      64         raise ValueError(
#      65             '"RootModel.__init__" accepts either a single positional argument or arbitrary keyword arguments'
#      66         )
#      67     root = data  # type: ignore
# ---> 68 self.__pydantic_validator__.validate_python(root, self_instance=self)
#
# ...
